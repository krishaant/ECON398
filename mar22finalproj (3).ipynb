# %%
library(haven)
library(stargazer)
library(dplyr)
library(infer)
library(ggplot2)
library(broom)
library(knitr)
library(kableExtra)
# Out:
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# Error in library(kableExtra): there is no package called ‘kableExtra’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
data <- read_dta("./cen_ind_2021_pumf_v2.dta")

# %%
colnames(data)
# Out:
#   [1] "ppsort"           "aboid"            "agegrp"
#   [4] "ageimm"           "attsch"           "bfnmemb"
#   [7] "bedrm"            "CFInc"            "CFInc_AT"
#  [10] "cfstat"           "chdbn"            "CIP2021"
#  [13] "CIP2021_STEM_SUM" "cma"              "condo"
#  [16] "COVID_ERB"        "cow"              "cqppb"
#  [19] "CapGn"            "CfSize"           "ChldC"
#  [22] "CitOth"           "Citizen"          "dist"
#  [25] "dpgrsum"          "dtype"            "EFDecile"
#  [28] "EFInc"            "EFInc_AT"         "eicbn"
#  [31] "ethder"           "EfDIMBM_2018"     "EfSize"
#  [34] "EmpIn"            "fol"              "fptwk"
#  [37] "Gender"           "genstat"          "GovtI"
#  [40] "GTRfs"            "HCORENEED_IND"    "hdgree"
#  [43] "HHInc"            "HHInc_AT"         "hhmrkinc"
#  [46] "hhsize"           "hhtype"           "hlmosten"
#  [49] "hlmostfr"         "hlmostno"         "hlregen"
#  [52] "hlregfr"          "hlregno"          "IMMCAT5"
#  [55] "immstat"          "IncTax"           "Invst"
#  [58] "jobperm"          "kol"              "lfact"
#  [61] "LICO_BT"          "LICO_AT"          "liprogtype"
#  [64] "LI_ELIG_OML_U18"  "locstud"          "LOC_ST_RES"
#  [67] "lstwrk"           "lwmosten"         "lwmostfr"
#  [70] "lwmostno"         "lwregen"          "lwregfr"
#  [73] "lwregno"          "LoLIMA"           "LoLIMB"
#  [76] "LOMBM_2018"       "mode"             "MTNEn"
#  [79] "MTNFr"            "mtnno"            "marsth"
#  [82] "Mob1"             "Mob5"             "MrkInc"
#  [85] "naics"            "NOC21"            "nol"
#  [88] "nos"              "oasgi"            "OtInc"
#  [91] "PKID25"           "PKID0_1"          "PKID15_24"
#  [94] "PKID2_5"          "PKID6_14"         "pkids"
#  [97] "pob"              "POBPAR1"          "POBPAR2"
# [100] "powst"            "pr"               "PR1"
# [103] "PR5"              "presmortg"        "prihm"
# [106] "pwdur"            "pwleave"          "pwocc"
# [109] "pwpr"             "regind"           "relig"
# [112] "repair"           "room"             "Retir"
# [115] "shelco"           "ssgrad"           "subsidy"
# [118] "SempI"            "tenur"            "TotInc"
# [121] "TotInc_AT"        "vismin"           "Value"
# [124] "wkswrk"           "wrkact"           "Wages"
# [127] "yrim"             "weight"           "WT1"
# [130] "WT2"              "WT3"              "WT4"
# [133] "WT5"              "WT6"              "WT7"
# [136] "WT8"              "WT9"              "WT10"
# [139] "WT11"             "WT12"             "WT13"
# [142] "WT14"             "WT15"             "WT16"

# %%
#removes NA rows
data <- data[data$CFInc != 88, ]

data <- data[data$agegrp != 88, ]

data <- data[data$genstat != 88, ]

data <- data[data$hdgree != 88, ]
data <- data[data$hdgree != 99, ]

data <- data[data$lfact != 88, ]
data <- data[data$lfact != 99, ]

# %%
data <- na.omit(data)

# %%
# simple regression 1 - CFInc (Income) based on Gentstat (First Gen / Second Gen Canadian)


reg_1 <-  lm(CFInc ~ genstat, data = data)

stargazer(reg_1, type = "text")
# Out:
# =================================================
#                          Dependent variable:
#                     -----------------------------
#                                 CFInc
# -------------------------------------------------
# genstat                       0.411***
#                                (0.006)
#
# Constant                      20.798***
#                                (0.021)
#
# -------------------------------------------------
# Observations                   980,868
# R2                              0.004
# Adjusted R2                     0.004
# Residual Std. Error      8.944 (df = 980866)
# F Statistic         4,277.340*** (df = 1; 980866)
# =================================================
# Note:                 *p<0.1; **p<0.05; ***p<0.01

# %%
# simple regression 2 - adding covariates for Gender and agegrp 

reg_2 <-  lm(CFInc ~ genstat + Gender + agegrp, data = data)

stargazer(reg_2, type = "text")
# Out:
# =================================================
#                          Dependent variable:
#                     -----------------------------
#                                 CFInc
# -------------------------------------------------
# genstat                       0.395***
#                                (0.006)
#
# Gender                        0.481***
#                                (0.018)
#
# agegrp                        -0.142***
#                                (0.001)
#
# Constant                      21.790***
#                                (0.037)
#
# -------------------------------------------------
# Observations                   980,868
# R2                              0.018
# Adjusted R2                     0.018
# Residual Std. Error      8.882 (df = 980864)
# F Statistic         6,071.070*** (df = 3; 980864)
# =================================================
# Note:                 *p<0.1; **p<0.05; ***p<0.01

# %%
# simple regression 3 - adding covariates for hdgree (education level) and lfact (labour force participation)

reg_3 <-  lm(CFInc ~ genstat + Gender + agegrp + hdgree + lfact, data = data)

stargazer(reg_3, type = "text")
# Out:
# ==================================================
#                          Dependent variable:
#                     ------------------------------
#                                 CFInc
# --------------------------------------------------
# genstat                        0.430***
#                                (0.006)
#
# Gender                         0.371***
#                                (0.017)
#
# agegrp                        -0.094***
#                                (0.001)
#
# hdgree                         0.274***
#                                (0.001)
#
# lfact                         -0.271***
#                                (0.001)
#
# Constant                      21.333***
#                                (0.039)
#
# --------------------------------------------------
# Observations                   980,868
# R2                              0.081
# Adjusted R2                     0.081
# Residual Std. Error      8.594 (df = 980862)
# F Statistic         17,254.280*** (df = 5; 980862)
# ==================================================
# Note:                  *p<0.1; **p<0.05; ***p<0.01

# %%
# simple regression 4 - by pr (province)

reg_4 <-  lm(CFInc ~ genstat + Gender + agegrp + hdgree + lfact + pr, data = data)

stargazer(reg_4, type = "text")
# Out:
# ==================================================
#                          Dependent variable:
#                     ------------------------------
#                                 CFInc
# --------------------------------------------------
# genstat                        0.461***
#                                (0.006)
#
# Gender                         0.371***
#                                (0.017)
#
# agegrp                        -0.094***
#                                (0.001)
#
# hdgree                         0.274***
#                                (0.001)
#
# lfact                         -0.270***
#                                (0.001)
#
# pr                             0.026***
#                                (0.001)
#
# Constant                      20.292***
#                                (0.047)
#
# --------------------------------------------------
# Observations                   980,868
# R2                              0.082
# Adjusted R2                     0.082
# Residual Std. Error      8.587 (df = 980861)
# F Statistic         14,645.080*** (df = 6; 980861)
# ==================================================
# Note:                  *p<0.1; **p<0.05; ***p<0.01

# %%
# checking for interaction effects 

reg_interaction <- lm(CFInc ~ genstat * hdgree + pr + Gender + agegrp + genstat * lfact, data = data)


stargazer(reg_interaction, type = "text")
# Out:
# ==================================================
#                          Dependent variable:
#                     ------------------------------
#                                 CFInc
# --------------------------------------------------
# genstat                        0.389***
#                                (0.007)
#
# hdgree                         0.283***
#                                (0.002)
#
# lfact                         -0.295***
#                                (0.002)
#
# pr                             0.026***
#                                (0.001)
#
# Gender                         0.368***
#                                (0.017)
#
# agegrp                        -0.093***
#                                (0.001)
#
# genstat:hdgree                -0.003***
#                                (0.001)
#
# genstat:lfact                  0.008***
#                                (0.001)
#
# Constant                      20.513***
#                                (0.048)
#
# --------------------------------------------------
# Observations                   980,868
# R2                              0.083
# Adjusted R2                     0.083
# Residual Std. Error      8.585 (df = 980859)
# F Statistic         11,070.260*** (df = 8; 980859)
# ==================================================
# Note:                  *p<0.1; **p<0.05; ***p<0.01

# %%
# Basic regressions
model1 <- lm(CFInc ~ genstat, data = data)
model2 <- lm(CFInc ~ genstat + Gender, data = data)
model3 <- lm(CFInc ~ genstat + Gender + agegrp, data = data)
model4 <- lm(CFInc ~ genstat + Gender + agegrp + hdgree, data = data)
model5 <- lm(CFInc ~ genstat * hdgree + pr + Gender + agegrp + genstat * lfact, data = data)

# Stargazer Table Output
stargazer(model1.1, model2.1, model3.1, model4.1, 
          type = "html", 
          title = "Degree on Generational Status",
          dep.var.labels = "Dependent Variable: CFInc",
          out = "income_table4.html")
# Out:
# <table style="text-align:center"><caption><strong>Degree on Generational Status</strong></caption>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable:</em></td></tr>
# <tr><td></td><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4">Dependent Variable: CFInc</td></tr>
# <tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">genstat</td><td>-0.022<sup>***</sup></td><td>-0.022<sup>***</sup></td><td>-0.022<sup>***</sup></td><td>-0.022<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.0003)</td><td>(0.0003)</td><td>(0.0003)</td><td>(0.0003)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">Gender</td><td></td><td>-0.035<sup>***</sup></td><td>-0.036<sup>***</sup></td><td>-0.042<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.001)</td><td>(0.001)</td><td>(0.001)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">agegrp</td><td></td><td></td><td>-0.006<sup>***</sup></td><td>-0.009<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.0001)</td><td>(0.0001)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">lfact</td><td></td><td></td><td></td><td>-0.007<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.0001)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">agegrp_dummy</td><td></td><td></td><td></td><td>-0.275<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.003)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">lfact:agegrp_dummy</td><td></td><td></td><td></td><td>0.005<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.0003)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">Constant</td><td>0.242<sup>***</sup></td><td>0.293<sup>***</sup></td><td>0.375<sup>***</sup></td><td>0.477<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.001)</td><td>(0.002)</td><td>(0.002)</td><td>(0.002)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">Observations</td><td>809,165</td><td>809,165</td><td>809,165</td><td>809,165</td></tr>
# <tr><td style="text-align:left">R<sup>2</sup></td><td>0.007</td><td>0.009</td><td>0.013</td><td>0.047</td></tr>
# <tr><td style="text-align:left">Adjusted R<sup>2</sup></td><td>0.007</td><td>0.009</td><td>0.013</td><td>0.047</td></tr>
# <tr><td style="text-align:left">Residual Std. Error</td><td>0.379 (df = 809163)</td><td>0.379 (df = 809162)</td><td>0.378 (df = 809161)</td><td>0.371 (df = 809158)</td></tr>
# <tr><td style="text-align:left">F Statistic</td><td>5,992.099<sup>***</sup> (df = 1; 809163)</td><td>3,848.424<sup>***</sup> (df = 2; 809162)</td><td>3,605.746<sup>***</sup> (df = 3; 809161)</td><td>6,625.303<sup>***</sup> (df = 6; 809158)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"><em>Note:</em></td><td colspan="4" style="text-align:right"><sup>*</sup>p<0.1; <sup>**</sup>p<0.05; <sup>***</sup>p<0.01</td></tr>
# </table>

# %%
#indivuals age 12-20
data <- data %>%
  mutate(agegrp_dummy = ifelse(agegrp %in% c("5", "6", "7"), 1, 0))

#dummy for bachelors degree to simplify 
data <- data %>%
  mutate(bachelors_degree = ifelse(hdgree %in% c(9), 1, 0))

# %%
#degree status on genstat 
# should be careful, meaning of hdgree is problematic 
model1.1 <- lm(bachelors_degree ~ genstat, data = data)
model2.1 <- lm(bachelors_degree ~ genstat + Gender, data = data)
model3.1 <- lm(bachelors_degree ~ genstat + Gender + agegrp, data = data)
model4.1 <- lm(bachelors_degree ~ genstat + Gender + agegrp + lfact*agegrp_dummy, data = data)

# Stargazer Table Output
stargazer(model1.1, model2.1, model3.1, model4.1, 
          type = "html", 
          title = "Degree on Generational Status",
          dep.var.labels = "Dependent Variable: bachelors_degree",
          out = "degree_table4.html")
# Out:
# <table style="text-align:center"><caption><strong>Degree on Generational Status</strong></caption>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable:</em></td></tr>
# <tr><td></td><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4">Dependent Variable: bachelors</td></tr>
# <tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">genstat</td><td>-0.022<sup>***</sup></td><td>-0.022<sup>***</sup></td><td>-0.022<sup>***</sup></td><td>-0.022<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.0003)</td><td>(0.0003)</td><td>(0.0003)</td><td>(0.0003)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">Gender</td><td></td><td>-0.035<sup>***</sup></td><td>-0.036<sup>***</sup></td><td>-0.042<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.001)</td><td>(0.001)</td><td>(0.001)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">agegrp</td><td></td><td></td><td>-0.006<sup>***</sup></td><td>-0.009<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.0001)</td><td>(0.0001)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">lfact</td><td></td><td></td><td></td><td>-0.007<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.0001)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">agegrp_dummy</td><td></td><td></td><td></td><td>-0.275<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.003)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">lfact:agegrp_dummy</td><td></td><td></td><td></td><td>0.005<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.0003)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">Constant</td><td>0.242<sup>***</sup></td><td>0.293<sup>***</sup></td><td>0.375<sup>***</sup></td><td>0.477<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.001)</td><td>(0.002)</td><td>(0.002)</td><td>(0.002)</td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td></td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">Observations</td><td>809,165</td><td>809,165</td><td>809,165</td><td>809,165</td></tr>
# <tr><td style="text-align:left">R<sup>2</sup></td><td>0.007</td><td>0.009</td><td>0.013</td><td>0.047</td></tr>
# <tr><td style="text-align:left">Adjusted R<sup>2</sup></td><td>0.007</td><td>0.009</td><td>0.013</td><td>0.047</td></tr>
# <tr><td style="text-align:left">Residual Std. Error</td><td>0.379 (df = 809163)</td><td>0.379 (df = 809162)</td><td>0.378 (df = 809161)</td><td>0.371 (df = 809158)</td></tr>
# <tr><td style="text-align:left">F Statistic</td><td>5,992.099<sup>***</sup> (df = 1; 809163)</td><td>3,848.424<sup>***</sup> (df = 2; 809162)</td><td>3,605.746<sup>***</sup> (df = 3; 809161)</td><td>6,625.303<sup>***</sup> (df = 6; 809158)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"><em>Note:</em></td><td colspan="4" style="text-align:right"><sup>*</sup>p<0.1; <sup>**</sup>p<0.05; <sup>***</sup>p<0.01</td></tr>
# </table>

# %%
extra1=lm(bachelors_degree ~ lfact*agegrp_dummy, data = data)

# %%
summary(extra1)
# Out:
# Call:
# lm(formula = bachelors_degree ~ lfact * agegrp_dummy, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.19887 -0.19887 -0.17293  0.01294  0.99869
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)         2.010e-01  4.183e-04  480.56   <2e-16 ***
# lfact              -2.161e-03  1.095e-05 -197.29   <2e-16 ***
# agegrp_dummy       -1.995e-01  1.691e-03 -117.96   <2e-16 ***
# lfact:agegrp_dummy  2.145e-03  2.836e-05   75.65   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3433 on 980864 degrees of freedom
# Multiple R-squared:  0.05411,	Adjusted R-squared:  0.0541
# F-statistic: 1.87e+04 on 3 and 980864 DF,  p-value: < 2.2e-16
